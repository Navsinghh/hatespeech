# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
import nltk
import re

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
stopword=set(stopwords.words('english'))
stemmer = nltk.SnowballStemmer("english")

# %%
data=pd.read_csv(r'C:\Users\navpr\jupi\data\labeled_data.csv')

# %%
print(data. head())
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
data["labels"] = data["class"]. map({0: "Hate Speech detected!", 1: "Offensive Speech detected!", 2: "No Hate and Offensive Speech"})
data = data[["tweet", "labels"]]

# %%
print(data. head())
# Out:
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                          labels
# 0  No Hate and Offensive Speech
# 1    Offensive Speech detected!
# 2    Offensive Speech detected!
# 3    Offensive Speech detected!
# 4    Offensive Speech detected!

# %%
def clean (text):
 text = str (text). lower()
 text = re. sub('[.?]', '', text) 
 text = re. sub('https?://\S+|www.\S+', '', text)
 text = re. sub('<.?>+', '', text)
 text = re. sub('[%s]' % re. escape(string. punctuation), '', text)
 text = re. sub('\n', '', text)
 text = re. sub('\w\d\w', '', text)
 text = [word for word in text.split(' ') if word not in stopword]
 text=" ". join(text)
 text = [stemmer. stem(word) for word in text. split(' ')]
 text=" ". join(text)
 return text

# %%
data["tweet"] = data["tweet"]

# %%
x = np. array(data["tweet"])
y = np. array(data["labels"])
cv = CountVectorizer()
X = cv. fit_transform(x)
# Splitting the Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#Model building
model = DecisionTreeClassifier()
#Training the model
model. fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Testing the model
y_pred = model. predict (X_test)
y_pred
# Out:
# array(['Offensive Speech detected!', 'Offensive Speech detected!',
#        'Offensive Speech detected!', ..., 'No Hate and Offensive Speech',
#        'No Hate and Offensive Speech', 'Offensive Speech detected!'],
#       dtype=object)

# %%
from sklearn. metrics import accuracy_score
print (accuracy_score (y_test,y_pred))
# Out:
# 0.8911847414109304

# %% [markdown]
# # Predicting the outcome

# %%
statement = "oh thanks"
statement = cv.transform([statement]).toarray()
print(model.predict(statement))
# Out:
# ['No Hate and Offensive Speech']

# %%
statement = "kill yourself"
statement = cv. transform([statement]). toarray()
print(model. predict(statement))
# Out:
# ['Offensive Speech detected!']

# %%
statement = "die gay"
statement = cv. transform([statement]). toarray()
print(model. predict(statement))
# Out:
# ['Offensive Speech detected!']
